# %%
import pandas as pd
fbk = pd.read_csv("result_FBK_init.txt.csv")
mfc = pd.read_csv("result_MFC_init.txt.csv")
print(mfc.loc[mfc['INIT'] == 'FlatStart'])
#print(mfc)
# Out:
#      Unnamed: 0 BANK       INIT ENV       TEST    HMM   INS  GRAM   CORR  \
# 0           148  MFC  FlatStart  D2  -CORETEST  324.0 -12.5   0.0  71.62
# 3           146  MFC  FlatStart  D2  -CORETEST  324.0 -10.0   0.0  72.12
# 5           138  MFC  FlatStart  D2  -CORETEST  204.0 -12.5   0.0  70.63
# 7           144  MFC  FlatStart  D2  -CORETEST  324.0  -7.5   0.0  72.87
# 8           136  MFC  FlatStart  D2  -CORETEST  204.0 -10.0   0.0  71.65
# 9           128  MFC  FlatStart  D2  -CORETEST  164.0 -12.5   0.0  70.47
# 11          126  MFC  FlatStart  D2  -CORETEST  164.0 -10.0   0.0  71.34
# 12          142  MFC  FlatStart  D2  -CORETEST  324.0  -5.0   0.0  73.70
# 14          134  MFC  FlatStart  D2  -CORETEST  204.0  -7.5   0.0  72.18
# 15          124  MFC  FlatStart  D2  -CORETEST  164.0  -7.5   0.0  72.00
# 19          118  MFC  FlatStart  D2  -CORETEST  124.0 -12.5   0.0  68.97
# 20          132  MFC  FlatStart  D2  -CORETEST  204.0  -5.0   0.0  72.87
# ...

# %%
df = pd.DataFrame(columns= ['BANK', 'INIT', 'ENV',
                        'MODEL','COMP','OCC AVG', 'OCC MIN', 'RO',
                        'TB'])
